# %% [markdown]
# # Avaliação AV04

# %% [markdown]
# Com base no arquivo que representa um recorte dos alvarás de curitiba (2019-10-01_Alvaras-Base_de_Dados_subset.csv), anexo à atividade e responda as 4 questões.
# Considere que campos *** são considerados como campos vazios.

# %% [markdown]
# 1. (20%) Agrupe os dados por atividade Principal e Atividade Secundária e apresente o subconjunto.

# %%
#Resposta

# %% [markdown]
# 2. (20%) Quais as 3 Atividades Principais com maior frequência?

# %%
#Resposta

# %% [markdown]
# 3. (10%) Apresente o histograma para esta distribuição de anos de vida:

# %%
#Resposta

# %% [markdown]
# 4. (25%) Quais são os 3 anos com maior início de empresas? Apresente o resultado com um gráfico do tipo Pizza.

# %%
#Resposta

# %% [markdown]
# 5. (25%) Quais os 3 bairros que possuem empresas com mais de 10 anos de idade? Apresente o resultado com um gráfico do tipo Pizza.

# %%
#Resposta
